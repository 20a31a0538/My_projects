# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Loading library and reading the dataset**

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("/content/gdrive/MyDrive/Colab Notebooks/NSE-Tataglobal.csv")
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %% [markdown]
# **Understanding the data**

# %%
df = df[::-1]      #inverse the  data
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# ...          ...     ...     ...     ...     ...     ...
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
#
#       Total Trade Quantity  Turnover (Lacs)
# 2034                658666           803.56
# 2033                293312           355.17
# 2032                281312           340.31
# 2031                658440           780.01
# 2030                586100           694.98
# ...                    ...              ...
# 4                  3423509          7999.55
# 3                  2349368          5503.90
# 2                  2240909          5248.60
# 1                  5082859         11859.95
# 0                  3069914          7162.35
#
# [2035 rows x 8 columns]

# %%
df.info()      # gives info about the data --->i.e; null values, & data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2035 entries, 2034 to 0
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  2035 non-null   object
#  1   Open                  2035 non-null   float64
#  2   High                  2035 non-null   float64
#  3   Low                   2035 non-null   float64
#  4   Last                  2035 non-null   float64
#  5   Close                 2035 non-null   float64
#  6   Total Trade Quantity  2035 non-null   int64
#  7   Turnover (Lacs)       2035 non-null   float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 127.3+ KB

# %%
df.describe()     # statistical data
# Out:
#               Open         High          Low         Last       Close  \
# count  2035.000000  2035.000000  2035.000000  2035.000000  2035.00000
# mean    149.713735   151.992826   147.293931   149.474251   149.45027
# std      48.664509    49.413109    47.931958    48.732570    48.71204
# min      81.100000    82.800000    80.000000    81.000000    80.95000
# 25%     120.025000   122.100000   118.300000   120.075000   120.05000
# 50%     141.500000   143.400000   139.600000   141.100000   141.25000
# 75%     157.175000   159.400000   155.150000   156.925000   156.90000
# max     327.700000   328.750000   321.650000   325.950000   325.75000
#
#        Total Trade Quantity  Turnover (Lacs)
# count          2.035000e+03      2035.000000
# mean           2.335681e+06      3899.980565
# std            2.091778e+06      4570.767877
# min            3.961000e+04        37.040000
# 25%            1.146444e+06      1427.460000
# 50%            1.783456e+06      2512.030000
# 75%            2.813594e+06      4539.015000
# max            2.919102e+07     55755.080000

# %%
df.drop_duplicates(inplace = True)      #removing  duplicaties     
df
# Out:
#             Date    Open    High     Low    Last   Close  \
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# ...          ...     ...     ...     ...     ...     ...
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
#
#       Total Trade Quantity  Turnover (Lacs)
# 2034                658666           803.56
# 2033                293312           355.17
# 2032                281312           340.31
# 2031                658440           780.01
# 2030                586100           694.98
# ...                    ...              ...
# 4                  3423509          7999.55
# 3                  2349368          5503.90
# 2                  2240909          5248.60
# 1                  5082859         11859.95
# 0                  3069914          7162.35
#
# [2035 rows x 8 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(df.corr(), annot=True)             #showing correlation between variables
plt.show()

# %%
df_high = df.reset_index()['High']
df_high
# Out:
# 0       123.00
# 1       122.00
# 2       121.95
# 3       121.00
# 4       119.50
#          ...
# 2030    239.20
# 2031    236.75
# 2032    240.00
# 2033    236.80
# 2034    235.95
# Name: High, Length: 2035, dtype: float64

# %%
plt.plot(df_high)
plt.show()

# %% [markdown]
# **Preprocessing the data**

# %%
from sklearn.preprocessing import MinMaxScaler

MMS = MinMaxScaler()
df_high = MMS.fit_transform(df_high.values.reshape(-1, 1))
df_high
# Out:
# array([[0.16344786],
#        [0.15938199],
#        [0.15917869],
#        ...,
#        [0.6391543 ],
#        [0.62614353],
#        [0.62268754]])

# %% [markdown]
# **Training the data and Test Spliting**

# %%
train_size = int(len(df_high) * 0.8)
test_size = len(df_high) - train_size

train_size, test_size
# Out:
# (1628, 407)

# %%
train_data, test_data = df_high[:train_size, :], df_high[train_size:, :1]
train_data.shape
# Out:
# (1628, 1)

# %% [markdown]
# **Preparing the the data**

# %%
# Previous 100 data points are stored 

def create_data(data, time_step):
  X_data, y_data = [], []

  for i in range(len(data) - time_step - 1):
    prev = data[i: i+time_step, 0]
    X_data.append(prev)
    y_data.append(data[i+time_step, 0])

  return np.array(X_data), np.array(y_data)

# %%
time_step = 100

X_train, y_train = create_data(train_data, time_step)
X_test, y_test = create_data(test_data, time_step)

# %%
# Make 3-D data(LSTM Requirement) (samples, time steps, features)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)
X_train.shape, y_train.shape
# Out:
# ((1527, 100, 1), (1527,))

# %%
import tensorflow as tf
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, LSTM

model = Sequential()

model.add(LSTM(50, return_sequences = True, input_shape = (100, 1)))
model.add(LSTM(50, return_sequences = True))
model.add(LSTM(50))
model.add(Dense(1))

model.compile(loss = 'mean_squared_error', optimizer = 'adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Predictions**

# %%
model.fit(X_train, y_train, validation_data = (X_test, y_test), epochs = 100, batch_size = 64, verbose = True)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 17s 380ms/step - loss: 0.0115 - val_loss: 0.0501
# Epoch 2/100
# 24/24 [==============================] - 9s 386ms/step - loss: 0.0019 - val_loss: 0.0073
# Epoch 3/100
# 24/24 [==============================] - 8s 344ms/step - loss: 8.6015e-04 - val_loss: 0.0040
# Epoch 4/100
# 24/24 [==============================] - 8s 343ms/step - loss: 7.8794e-04 - val_loss: 0.0041
# Epoch 5/100
# 24/24 [==============================] - 8s 347ms/step - loss: 7.7135e-04 - val_loss: 0.0038
# Epoch 6/100
# 24/24 [==============================] - 8s 349ms/step - loss: 7.2843e-04 - val_loss: 0.0033
# Epoch 7/100
# 24/24 [==============================] - 8s 342ms/step - loss: 6.9920e-04 - val_loss: 0.0037
# Epoch 8/100
# 24/24 [==============================] - 8s 342ms/step - loss: 6.6183e-04 - val_loss: 0.0054
# Epoch 9/100
# 24/24 [==============================] - 8s 345ms/step - loss: 6.8676e-04 - val_loss: 0.0029
# Epoch 10/100
# 24/24 [==============================] - 8s 348ms/step - loss: 6.7917e-04 - val_loss: 0.0035
# Epoch 11/100
# 24/24 [==============================] - 8s 345ms/step - loss: 6.0270e-04 - val_loss: 0.0042
# Epoch 12/100
# 24/24 [==============================] - 9s 348ms/step - loss: 5.7491e-04 - val_loss: 0.0047
# Epoch 13/100
# 24/24 [==============================] - 8s 343ms/step - loss: 5.4383e-04 - val_loss: 0.0047
# Epoch 14/100
# 24/24 [==============================] - 8s 354ms/step - loss: 5.2948e-04 - val_loss: 0.0074
# Epoch 15/100
# 24/24 [==============================] - 8s 348ms/step - loss: 5.2831e-04 - val_loss: 0.0081
# Epoch 16/100
# 24/24 [==============================] - 8s 350ms/step - loss: 5.2303e-04 - val_loss: 0.0065
# Epoch 17/100
# 24/24 [==============================] - 8s 345ms/step - loss: 4.8888e-04 - val_loss: 0.0073
# Epoch 18/100
# 24/24 [==============================] - 8s 344ms/step - loss: 4.9564e-04 - val_loss: 0.0082
# Epoch 19/100
# 24/24 [==============================] - 8s 345ms/step - loss: 4.6129e-04 - val_loss: 0.0086
# Epoch 20/100
# 24/24 [==============================] - 8s 347ms/step - loss: 4.3777e-04 - val_loss: 0.0094
# Epoch 21/100
# 24/24 [==============================] - 8s 346ms/step - loss: 4.3039e-04 - val_loss: 0.0083
# Epoch 22/100
# 24/24 [==============================] - 12s 504ms/step - loss: 4.2636e-04 - val_loss: 0.0070
# Epoch 23/100
# 24/24 [==============================] - 8s 343ms/step - loss: 4.0419e-04 - val_loss: 0.0073
# Epoch 24/100
# 24/24 [==============================] - 8s 343ms/step - loss: 3.9453e-04 - val_loss: 0.0049
# Epoch 25/100
# 24/24 [==============================] - 8s 340ms/step - loss: 4.0922e-04 - val_loss: 0.0054
# Epoch 26/100
# 24/24 [==============================] - 8s 346ms/step - loss: 4.8235e-04 - val_loss: 0.0058
# Epoch 27/100
# 24/24 [==============================] - 8s 343ms/step - loss: 3.7886e-04 - val_loss: 0.0052
# Epoch 28/100
# 24/24 [==============================] - 8s 349ms/step - loss: 3.5080e-04 - val_loss: 0.0061
# Epoch 29/100
# 24/24 [==============================] - 8s 347ms/step - loss: 3.4383e-04 - val_loss: 0.0081
# Epoch 30/100
# 24/24 [==============================] - 8s 349ms/step - loss: 3.3360e-04 - val_loss: 0.0060
# Epoch 31/100
# 24/24 [==============================] - 8s 346ms/step - loss: 3.2763e-04 - val_loss: 0.0075
# Epoch 32/100
# 24/24 [==============================] - 8s 346ms/step - loss: 3.1713e-04 - val_loss: 0.0031
# Epoch 33/100
# 24/24 [==============================] - 8s 347ms/step - loss: 3.1221e-04 - val_loss: 0.0054
# Epoch 34/100
# 24/24 [==============================] - 8s 348ms/step - loss: 3.2752e-04 - val_loss: 0.0042
# Epoch 35/100
# 24/24 [==============================] - 8s 353ms/step - loss: 2.9205e-04 - val_loss: 0.0053
# Epoch 36/100
# 24/24 [==============================] - 8s 349ms/step - loss: 2.9703e-04 - val_loss: 0.0040
# Epoch 37/100
# 24/24 [==============================] - 8s 350ms/step - loss: 2.9483e-04 - val_loss: 0.0076
# Epoch 38/100
# 24/24 [==============================] - 9s 357ms/step - loss: 2.8922e-04 - val_loss: 0.0021
# Epoch 39/100
# 24/24 [==============================] - 8s 354ms/step - loss: 2.6918e-04 - val_loss: 0.0025
# Epoch 40/100
# 24/24 [==============================] - 8s 346ms/step - loss: 2.7933e-04 - val_loss: 0.0062
# Epoch 41/100
# 24/24 [==============================] - 8s 344ms/step - loss: 2.5531e-04 - val_loss: 0.0055
# Epoch 42/100
# 24/24 [==============================] - 8s 351ms/step - loss: 2.4481e-04 - val_loss: 0.0018
# Epoch 43/100
# 24/24 [==============================] - 8s 343ms/step - loss: 2.3902e-04 - val_loss: 0.0039
# Epoch 44/100
# 24/24 [==============================] - 8s 344ms/step - loss: 2.1894e-04 - val_loss: 0.0025
# Epoch 45/100
# 24/24 [==============================] - 8s 344ms/step - loss: 2.2692e-04 - val_loss: 0.0050
# Epoch 46/100
# 24/24 [==============================] - 8s 348ms/step - loss: 2.3164e-04 - val_loss: 0.0017
# Epoch 47/100
# 24/24 [==============================] - 8s 347ms/step - loss: 2.0298e-04 - val_loss: 0.0029
# Epoch 48/100
# 24/24 [==============================] - 8s 345ms/step - loss: 2.0039e-04 - val_loss: 0.0049
# Epoch 49/100
# 24/24 [==============================] - 8s 350ms/step - loss: 2.0737e-04 - val_loss: 0.0013
# Epoch 50/100
# 24/24 [==============================] - 8s 348ms/step - loss: 1.9073e-04 - val_loss: 0.0018
# Epoch 51/100
# 24/24 [==============================] - 8s 347ms/step - loss: 1.9028e-04 - val_loss: 0.0015
# Epoch 52/100
# 24/24 [==============================] - 8s 346ms/step - loss: 1.7966e-04 - val_loss: 0.0027
# Epoch 53/100
# 24/24 [==============================] - 8s 342ms/step - loss: 1.7980e-04 - val_loss: 0.0020
# Epoch 54/100
# 24/24 [==============================] - 8s 347ms/step - loss: 1.7320e-04 - val_loss: 0.0024
# Epoch 55/100
# 24/24 [==============================] - 9s 356ms/step - loss: 1.8856e-04 - val_loss: 0.0013
# Epoch 56/100
# 24/24 [==============================] - 8s 343ms/step - loss: 1.6647e-04 - val_loss: 0.0010
# Epoch 57/100
# 24/24 [==============================] - 8s 344ms/step - loss: 1.5981e-04 - val_loss: 0.0027
# Epoch 58/100
# 24/24 [==============================] - 11s 448ms/step - loss: 1.5267e-04 - val_loss: 0.0035
# Epoch 59/100
# 24/24 [==============================] - 10s 408ms/step - loss: 1.7282e-04 - val_loss: 0.0037
# Epoch 60/100
# 24/24 [==============================] - 8s 348ms/step - loss: 1.6032e-04 - val_loss: 0.0023
# Epoch 61/100
# 24/24 [==============================] - 8s 345ms/step - loss: 1.4948e-04 - val_loss: 0.0024
# Epoch 62/100
# 24/24 [==============================] - 8s 347ms/step - loss: 1.5029e-04 - val_loss: 0.0020
# Epoch 63/100
# 24/24 [==============================] - 8s 344ms/step - loss: 1.4237e-04 - val_loss: 0.0017
# Epoch 64/100
# 24/24 [==============================] - 8s 350ms/step - loss: 1.4698e-04 - val_loss: 0.0030
# Epoch 65/100
# 24/24 [==============================] - 9s 356ms/step - loss: 1.7109e-04 - val_loss: 0.0035
# Epoch 66/100
# 24/24 [==============================] - 9s 361ms/step - loss: 1.4107e-04 - val_loss: 0.0019
# Epoch 67/100
# 24/24 [==============================] - 8s 355ms/step - loss: 1.6469e-04 - val_loss: 0.0035
# Epoch 68/100
# 24/24 [==============================] - 8s 349ms/step - loss: 1.3229e-04 - val_loss: 0.0022
# Epoch 69/100
# 24/24 [==============================] - 8s 351ms/step - loss: 1.3926e-04 - val_loss: 0.0024
# Epoch 70/100
# 24/24 [==============================] - 8s 350ms/step - loss: 1.3508e-04 - val_loss: 0.0017
# Epoch 71/100
# 24/24 [==============================] - 8s 350ms/step - loss: 1.3483e-04 - val_loss: 0.0018
# Epoch 72/100
# 24/24 [==============================] - 9s 355ms/step - loss: 1.2661e-04 - val_loss: 0.0016
# Epoch 73/100
# 24/24 [==============================] - 8s 345ms/step - loss: 1.2503e-04 - val_loss: 0.0028
# Epoch 74/100
# 24/24 [==============================] - 8s 350ms/step - loss: 1.2110e-04 - val_loss: 0.0015
# Epoch 75/100
# 24/24 [==============================] - 8s 345ms/step - loss: 1.2343e-04 - val_loss: 0.0023
# Epoch 76/100
# 24/24 [==============================] - 8s 346ms/step - loss: 1.3584e-04 - val_loss: 0.0023
# Epoch 77/100
# 24/24 [==============================] - 8s 348ms/step - loss: 1.4233e-04 - val_loss: 0.0023
# Epoch 78/100
# 24/24 [==============================] - 8s 349ms/step - loss: 1.4447e-04 - val_loss: 0.0027
# Epoch 79/100
# 24/24 [==============================] - 8s 347ms/step - loss: 1.2011e-04 - val_loss: 0.0015
# Epoch 80/100
# 24/24 [==============================] - 8s 346ms/step - loss: 1.2738e-04 - val_loss: 0.0028
# Epoch 81/100
# 24/24 [==============================] - 8s 346ms/step - loss: 1.2306e-04 - val_loss: 0.0041
# Epoch 82/100
# 24/24 [==============================] - 8s 350ms/step - loss: 1.2464e-04 - val_loss: 0.0024
# Epoch 83/100
# 24/24 [==============================] - 8s 345ms/step - loss: 1.3229e-04 - val_loss: 0.0013
# Epoch 84/100
# 24/24 [==============================] - 8s 349ms/step - loss: 1.3121e-04 - val_loss: 0.0014
# Epoch 85/100
# 24/24 [==============================] - 8s 346ms/step - loss: 1.1294e-04 - val_loss: 0.0017
# Epoch 86/100
# 24/24 [==============================] - 8s 351ms/step - loss: 1.2275e-04 - val_loss: 0.0019
# Epoch 87/100
# 24/24 [==============================] - 8s 347ms/step - loss: 1.3770e-04 - val_loss: 0.0030
# Epoch 88/100
# 24/24 [==============================] - 8s 350ms/step - loss: 1.2651e-04 - val_loss: 0.0013
# Epoch 89/100
# 24/24 [==============================] - 8s 352ms/step - loss: 1.4070e-04 - val_loss: 0.0016
# Epoch 90/100
# 24/24 [==============================] - 8s 351ms/step - loss: 1.3324e-04 - val_loss: 0.0023
# Epoch 91/100
# 24/24 [==============================] - 8s 352ms/step - loss: 1.1922e-04 - val_loss: 0.0028
# Epoch 92/100
# 24/24 [==============================] - 8s 347ms/step - loss: 1.2036e-04 - val_loss: 0.0024
# Epoch 93/100
# 24/24 [==============================] - 8s 349ms/step - loss: 1.2137e-04 - val_loss: 0.0023
# Epoch 94/100
# 24/24 [==============================] - 8s 347ms/step - loss: 1.1437e-04 - val_loss: 0.0026
# Epoch 95/100
# 24/24 [==============================] - 12s 513ms/step - loss: 1.2300e-04 - val_loss: 0.0019
# Epoch 96/100
# 24/24 [==============================] - 8s 352ms/step - loss: 1.2081e-04 - val_loss: 0.0021
# Epoch 97/100
# 24/24 [==============================] - 8s 350ms/step - loss: 1.2229e-04 - val_loss: 0.0032
# Epoch 98/100
# 24/24 [==============================] - 8s 348ms/step - loss: 1.1468e-04 - val_loss: 0.0023
# Epoch 99/100
# 24/24 [==============================] - 8s 346ms/step - loss: 1.2751e-04 - val_loss: 0.0036
# Epoch 100/100
# 24/24 [==============================] - 8s 350ms/step - loss: 1.2570e-04 - val_loss: 0.0024

# %% [markdown]
# Plotting

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)


# from math import sqrt
# from sklearn.metrics import  mean_squared_error

# rmse_train = sqrt(mean_squared_error(y_train, train_predict))
# rmse_test = sqrt(mean_squared_error(y_test, train_predict))
# rmse_train, rmse_test */

# %% [markdown]
# **Metric**

# %%
from math import sqrt
from sklearn.metrics import  mean_squared_error

rmse_train = sqrt(mean_squared_error(y_train, train_predict))
rmse_test = sqrt(mean_squared_error(y_test, test_predict))
rmse_train, rmse_test
# Out:
# (0.01066211165213548, 0.04917031763383358)

# %%
train_predict = MMS.inverse_transform(train_predict)
test_predict = MMS.inverse_transform(test_predict)

# %%
look_back = 100

trainPredictPlot = np.empty_like(df_high)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back: len(train_predict) + look_back, :] = train_predict

testPredictPlot = np.empty_like(df_high)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_predict) + (look_back * 2) + 1: len(df_high) - 1, :] = test_predict

# %%
plt.plot(MMS.inverse_transform(df_high))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)

plt.legend(labels = ['Complete data', 'Train data', 'Predicted data'])
plt.show()
